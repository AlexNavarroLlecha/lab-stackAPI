# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import pandas as pd
import numpy as np
from stackapi import StackAPI
import json

SITE = StackAPI('stackoverflow')

comments = SITE.fetch('comments')
comments['items']
comments_df = pd.DataFrame(comments)

# %%
comments_df
# Out:
#      backoff  has_more  page  quota_max  quota_remaining  total  \
# 0          0      True     5        300              300      0
# 1          0      True     5        300              300      0
# 2          0      True     5        300              300      0
# 3          0      True     5        300              300      0
# 4          0      True     5        300              300      0
# ..       ...       ...   ...        ...              ...    ...
# 495        0      True     5        300              300      0
# 496        0      True     5        300              300      0
# 497        0      True     5        300              300      0
# 498        0      True     5        300              300      0
# 499        0      True     5        300              300      0
#
#                                                  items
# 0    {'owner': {'reputation': 639, 'user_id': 75195...
# 1    {'owner': {'reputation': 1, 'user_id': 1153281...
# ...

# %%
#comments_df = comments_df[['creation_date','post_id','comment_id','owner','score','reply_to_user']]

# %%
#comments_df['owner_user_id']= comments_df['owner'].apply(lambda x: x['user_id'])

# %%
#comments_df
# Out:
#                                                  owner  edited  score  \
# 0    {'reputation': 809, 'user_id': 1137406, 'user_...   False      0
# 1    {'reputation': 1724, 'user_id': 7926183, 'user...   False      0
# 2    {'reputation': 1, 'user_id': 12263263, 'user_t...   False      0
# 3    {'reputation': 51, 'user_id': 7174456, 'user_t...   False      0
# 4    {'reputation': 1446, 'user_id': 1503846, 'user...   False      0
# ..                                                 ...     ...    ...
# 495  {'reputation': 413536, 'user_id': 1048572, 'us...   False      0
# 496  {'reputation': 972, 'user_id': 4870078, 'user_...   False      0
# 497  {'reputation': 185, 'user_id': 9988108, 'user_...   False      0
# 498  {'reputation': 443, 'user_id': 2028853, 'user_...   False      0
# 499  {'reputation': 14, 'user_id': 5668586, 'user_t...   False      0
#
#      creation_date   post_id  comment_id  \
# 0       1573128563  58709835   103785355
# ...

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %% [markdown]
# Looking with the timestamp of today and the last month with the argument 'is_answered' true

# %%
# your code here
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1570532113, todate=1573214113,is_answered =False)
questions_df = pd.DataFrame(questions['items'])
questions_df
# Out:
#                                                   tags  \
# 0                            [msbuild, nuget, project]
# 1       [javascript, function, functional-programming]
# 2                              [mysql, join, subquery]
# 3    [python, pygame, operating-system, pyglet, win...
# 4                                    [pyqt, pyqtgraph]
# ..                                                 ...
# 495                                    [php, reactphp]
# 496                          [xcode, ios13, xcode11.1]
# 497                               [google-apps-script]
# 498                               [postgresql, docker]
# 499  [javascript, arrays, algorithm, recursion, dra...
#
#                                                  owner  is_answered  \
# 0    {'reputation': 1939, 'user_id': 57737, 'user_t...         True
# 1    {'reputation': 662, 'user_id': 3106343, 'user_...         True
# 2    {'reputation': 367, 'user_id': 8252915, 'user_...        False
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questions = SITE.fetch('questions', todate=1573214113,tagged = 'python')
questions_df = pd.DataFrame(questions['items'])
questions_df.loc[questions_df['score']>=5]
# Out:
#                                                   tags  \
# 0           [python, transactions, sqlite, autocommit]
# 2                                   [python, anaconda]
# 6                            [python, multiprocessing]
# 11                         [javascript, python, flask]
# 22                       [python, pandas, conditional]
# 25                                      [python, list]
# 27               [python, python-2.7, dictionary, key]
# 34                           [python, testing, pytest]
# 39   [python, python-3.x, machine-learning, scikit-...
# 41                                    [python, pandas]
# 52                [python, pandas, chained-assignment]
# 61                             [python, http, sniffer]
# 83                                [python, proxy, pip]
# 136                                           [python]
# 147        [python, django, python-2.7, django-models]
# 148                                      [python, jwt]
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answers = SITE.fetch('answers', ids = [6784,6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 22434,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
